# %% [markdown]
# # Interactions - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll explore interactions in the Boston Housing data set.

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Understand what interactions are
# - Understand how to accommodate for interactions in regression

# %% [markdown]
# ## Build a baseline model

# %% [markdown]
# You'll use a couple of built-in functions, which we imported for you below.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.datasets import load_boston
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import the Boston data set using `load_boston()`. We won't bother to preprocess the data in this lab. If you still want to build a model in the end, you can do that, but this lab will just focus on finding meaningful insights in interactions and how they can improve $R^2$ values.

# %%
regression = LinearRegression()
boston = load_boston()

# %% [markdown]
# Create a baseline model which includes all the variables in the Boston housing data set to predict the house prices. Then use 10-fold cross-validation and report the mean $R^2$ value as the baseline $R^2$.

# %%
df = pd.DataFrame(boston.data, columns=boston["feature_names"])
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df_bak = df

# %%
df_bak.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
X = boston.data
y = boston.target

# %%
## code here
#regression.fit(df,boston.target)

# %%
def check_model(model,X,y):
    crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
    outs = cross_val_score(model, X,y , cv = crossvalidation , scoring = "r2",verbose = False)
    return outs.mean()

# %%
model=LinearRegression()
base_r2 = check_model(model,X,y)
base_r2
# Out:
# 0.7190106820189475

# %% [markdown]
# ## See how interactions improve your baseline

# %% [markdown]
# Next, create all possible combinations of interactions, loop over them and add them to the baseline model one by one to see how they affect the $R^2$. We'll look at the 3 interactions which have the biggest effect on our $R^2$, so print out the top 3 combinations.
#
# You will create a for loop to loop through all the combinations of 2 predictors. You can use `combinations` from itertools to create a list of all the pairwise combinations. To find more info on how this is done, have a look [here](https://docs.python.org/2/library/itertools.html).

# %%
from itertools import combinations
combinations = list(combinations(boston.feature_names, 2))
r2_list = [{"interaction": "base",
          "r2": base_r2,
          "index":0}]
i = r2_list[0]["index"]
for combination in combinations:
    i += 1
    f1=combination[0]
    f2=combination[1]
    #print(f1+"_"+f2)
    df[f1+"_"+f2] = df[f1]*df[f2]
    y = boston.target
    X = np.asarray(df_bak)
    model=LinearRegression()
    r2 = check_model(model,X,y)
    r2_list.append({"interaction":f1+"_"+f2,
                   "r2": r2,
                   "index": i})

# %%
## code to find top 3 interactions by R^2 value here
#r2_list[i]["r2"]-r2_list[i-1]["r2"]
diff_list = [(r2_list[i]["r2"],r2_list[i]["interaction"], i) for i in range(1,len(r2_list))]

# %%
diff_list.sort()
diff_list[-3:]
# Out:
# [(0.8528562547454153, 'TAX_LSTAT', 75),
#  (0.8531244563920304, 'TAX_B', 74),
#  (0.8532317331728411, 'TAX_PTRATIO', 73)]

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#      ...      RAD_TAX  RAD_PTRATIO    RAD_B  RAD_LSTAT  TAX_PTRATIO  \
# 0    ...        296.0         15.3   396.90       4.98       4528.8
# 1    ...        484.0         35.6   793.80      18.28       4307.6
# 2    ...        484.0         35.6   785.66       8.06       4307.6
# 3    ...        666.0         56.1  1183.89       8.82       4151.4
# 4    ...        666.0         56.1  1190.70      15.99       4151.4
#
#        TAX_B  TAX_LSTAT  PTRATIO_B  PTRATIO_LSTAT    B_LSTAT
# 0  117482.40    1474.08   6072.570         76.194  1976.5620
# 1   96049.80    2211.88   7064.820        162.692  3627.6660
# 2   95064.86     975.26   6992.374         71.734  1583.1049
# 3   87607.86     652.68   7379.581         54.978  1160.2122
# 4   88111.80    1183.26   7422.030         99.671  2115.4770
#
# [5 rows x 91 columns]

# %%
df_bak.head
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# 11    0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267   5.0  311.0
# 12    0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509   5.0  311.0
# 13    0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075   4.0  307.0
# 14    0.63796   0.0   8.14   0.0  0.538  6.096   84.5  4.4619   4.0  307.0
# 15    0.62739   0.0   8.14   0.0  0.538  5.834   56.5  4.4986   4.0  307.0
# 16    1.05393   0.0   8.14   0.0  0.538  5.935   29.3  4.4986   4.0  307.0
# 17    0.78420   0.0   8.14   0.0  0.538  5.990   81.7  4.2579   4.0  307.0
# 18    0.80271   0.0   8.14   0.0  0.538  5.456   36.6  3.7965   4.0  307.0
# 19    0.72580   0.0   8.14   0.0  0.538  5.727   69.5  3.7965   4.0  307.0
# 20    1.25179   0.0   8.14   0.0  0.538  5.570   98.1  3.7979   4.0  307.0
# 21    0.85204   0.0   8.14   0.0  0.538  5.965   89.2  4.0123   4.0  307.0
# 22    1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 23    0.98843   0.0   8.14   0.0  0.538  5.813  100.0  4.0952   4.0  307.0
# 24    0.75026   0.0   8.14   0.0  0.538  5.924   94.1  4.3996   4.0  307.0
# 25    0.84054   0.0   8.14   0.0  0.538  5.599   85.7  4.4546   4.0  307.0
# 26    0.67191   0.0   8.14   0.0  0.538  5.813   90.3  4.6820   4.0  307.0
# 27    0.95577   0.0   8.14   0.0  0.538  6.047   88.8  4.4534   4.0  307.0
# 28    0.77299   0.0   8.14   0.0  0.538  6.495   94.4  4.4547   4.0  307.0
# 29    1.00245   0.0   8.14   0.0  0.538  6.674   87.3  4.2390   4.0  307.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 476   4.87141   0.0  18.10   0.0  0.614  6.484   93.6  2.3053  24.0  666.0
# 477  15.02340   0.0  18.10   0.0  0.614  5.304   97.3  2.1007  24.0  666.0
# 478  10.23300   0.0  18.10   0.0  0.614  6.185   96.7  2.1705  24.0  666.0
# 479  14.33370   0.0  18.10   0.0  0.614  6.229   88.0  1.9512  24.0  666.0
# 480   5.82401   0.0  18.10   0.0  0.532  6.242   64.7  3.4242  24.0  666.0
# 481   5.70818   0.0  18.10   0.0  0.532  6.750   74.9  3.3317  24.0  666.0
# 482   5.73116   0.0  18.10   0.0  0.532  7.061   77.0  3.4106  24.0  666.0
# 483   2.81838   0.0  18.10   0.0  0.532  5.762   40.3  4.0983  24.0  666.0
# 484   2.37857   0.0  18.10   0.0  0.583  5.871   41.9  3.7240  24.0  666.0
# 485   3.67367   0.0  18.10   0.0  0.583  6.312   51.9  3.9917  24.0  666.0
# 486   5.69175   0.0  18.10   0.0  0.583  6.114   79.8  3.5459  24.0  666.0
# 487   4.83567   0.0  18.10   0.0  0.583  5.905   53.2  3.1523  24.0  666.0
# 488   0.15086   0.0  27.74   0.0  0.609  5.454   92.7  1.8209   4.0  711.0
# 489   0.18337   0.0  27.74   0.0  0.609  5.414   98.3  1.7554   4.0  711.0
# 490   0.20746   0.0  27.74   0.0  0.609  5.093   98.0  1.8226   4.0  711.0
# 491   0.10574   0.0  27.74   0.0  0.609  5.983   98.8  1.8681   4.0  711.0
# 492   0.11132   0.0  27.74   0.0  0.609  5.983   83.5  2.1099   4.0  711.0
# 493   0.17331   0.0   9.69   0.0  0.585  5.707   54.0  2.3817   6.0  391.0
# 494   0.27957   0.0   9.69   0.0  0.585  5.926   42.6  2.3817   6.0  391.0
# 495   0.17899   0.0   9.69   0.0  0.585  5.670   28.8  2.7986   6.0  391.0
# 496   0.28960   0.0   9.69   0.0  0.585  5.390   72.9  2.7986   6.0  391.0
# 497   0.26838   0.0   9.69   0.0  0.585  5.794   70.6  2.8927   6.0  391.0
# 498   0.23912   0.0   9.69   0.0  0.585  6.019   65.3  2.4091   6.0  391.0
# 499   0.17783   0.0   9.69   0.0  0.585  5.569   73.5  2.3999   6.0  391.0
# 500   0.22438   0.0   9.69   0.0  0.585  6.027   79.7  2.4982   6.0  391.0
# 501   0.06263   0.0  11.93   0.0  0.573  6.593   69.1  2.4786   1.0  273.0
# 502   0.04527   0.0  11.93   0.0  0.573  6.120   76.7  2.2875   1.0  273.0
# 503   0.06076   0.0  11.93   0.0  0.573  6.976   91.0  2.1675   1.0  273.0
# 504   0.10959   0.0  11.93   0.0  0.573  6.794   89.3  2.3889   1.0  273.0
# 505   0.04741   0.0  11.93   0.0  0.573  6.030   80.8  2.5050   1.0  273.0
#
#         ...      RAD_TAX  RAD_PTRATIO    RAD_B  RAD_LSTAT  TAX_PTRATIO  \
# 0       ...        296.0         15.3   396.90       4.98       4528.8
# 1       ...        484.0         35.6   793.80      18.28       4307.6
# 2       ...        484.0         35.6   785.66       8.06       4307.6
# 3       ...        666.0         56.1  1183.89       8.82       4151.4
# 4       ...        666.0         56.1  1190.70      15.99       4151.4
# 5       ...        666.0         56.1  1182.36      15.63       4151.4
# 6       ...       1555.0         76.0  1978.00      62.15       4727.2
# 7       ...       1555.0         76.0  1984.50      95.75       4727.2
# 8       ...       1555.0         76.0  1933.15     149.65       4727.2
# 9       ...       1555.0         76.0  1933.55      85.50       4727.2
# 10      ...       1555.0         76.0  1962.60     102.25       4727.2
# 11      ...       1555.0         76.0  1984.50      66.35       4727.2
# 12      ...       1555.0         76.0  1952.50      78.55       4727.2
# 13      ...       1228.0         84.0  1587.60      33.04       6447.0
# 14      ...       1228.0         84.0  1520.08      41.04       6447.0
# 15      ...       1228.0         84.0  1582.48      33.88       6447.0
# 16      ...       1228.0         84.0  1547.40      26.32       6447.0
# 17      ...       1228.0         84.0  1547.00      58.68       6447.0
# 18      ...       1228.0         84.0  1155.96      46.76       6447.0
# 19      ...       1228.0         84.0  1563.80      45.12       6447.0
# 20      ...       1228.0         84.0  1506.28      84.08       6447.0
# 21      ...       1228.0         84.0  1570.12      55.32       6447.0
# 22      ...       1228.0         84.0  1587.60      74.88       6447.0
# 23      ...       1228.0         84.0  1578.16      79.52       6447.0
# 24      ...       1228.0         84.0  1577.32      65.20       6447.0
# 25      ...       1228.0         84.0  1213.68      66.04       6447.0
# 26      ...       1228.0         84.0  1507.52      59.24       6447.0
# 27      ...       1228.0         84.0  1225.52      69.12       6447.0
# 28      ...       1228.0         84.0  1551.76      51.20       6447.0
# 29      ...       1228.0         84.0  1520.92      47.92       6447.0
# ..      ...          ...          ...      ...        ...          ...
# 476     ...      15984.0        484.8  9509.04     448.32      13453.2
# 477     ...      15984.0        484.8  8387.52     597.84      13453.2
# 478     ...      15984.0        484.8  9112.80     432.72      13453.2
# 479     ...      15984.0        484.8  9199.68     314.64      13453.2
# 480     ...      15984.0        484.8  9525.60     257.76      13453.2
# 481     ...      15984.0        484.8  9433.68     185.76      13453.2
# 482     ...      15984.0        484.8  9486.72     168.24      13453.2
# 483     ...      15984.0        484.8  9430.08     250.08      13453.2
# 484     ...      15984.0        484.8  8897.52     320.16      13453.2
# 485     ...      15984.0        484.8  9326.88     253.92      13453.2
# 486     ...      15984.0        484.8  9424.32     359.52      13453.2
# 487     ...      15984.0        484.8  9317.28     274.80      13453.2
# 488     ...       2844.0         80.4  1580.36      72.24      14291.1
# 489     ...       2844.0         80.4  1376.20      95.88      14291.1
# 490     ...       2844.0         80.4  1273.72     118.72      14291.1
# 491     ...       2844.0         80.4  1560.44      72.28      14291.1
# 492     ...       2844.0         80.4  1587.60      53.40      14291.1
# 493     ...       2346.0        115.2  2381.40      72.06       7507.2
# 486  261524.88    9976.68   7932.136        302.596   5882.3464
# 487  258554.52    7625.70   7842.044        231.290   4445.1190
# 488  280908.99   12840.66   7941.309        363.006   7135.3254
# 489  244619.55   17042.67   6915.405        481.797   8246.8785
# 490  226403.73   21102.48   6400.443        596.568   9451.0024
# 491  277368.21   12847.77   7841.211        363.207   7049.2877
# 492  282195.90    9491.85   7977.690        268.335   5298.6150
# 493  155187.90    4695.91   7620.480        230.592   4766.7690
# 494  155187.90    5313.69   7620.480        260.928   5393.8710
# 495  153776.39    6881.60   7551.168        337.920   6921.9040
# 496  155187.90    8265.74   7620.480        405.888   8390.4660
# 497  155187.90    5513.10   7620.480        270.720   5596.2900
# 498  155187.90    5051.72   7620.480        248.064   5127.9480
# 499  154746.07    5904.10   7598.784        289.920   5976.1270
# 500  155187.90    5603.03   7620.480        275.136   5687.5770
# 501  107013.27    2639.91   8231.790        203.070   3790.5433
# 502  108353.70    2478.84   8334.900        190.680   3603.8520
# 503  108353.70    1539.72   8334.900        118.440   2238.5160
# 504  107411.85    1769.04   8262.450        136.080   2549.5560
# 505  108353.70    2151.24   8334.900        165.480   3127.5720
#
# [506 rows x 91 columns]

# %% [markdown]
# ## Look at the top 3 interactions: "RM" as a confounding factor

# %% [markdown]
# The top three interactions seem to involve "RM", the number of rooms as a confounding variable for all of them. Let's have a look at interaction plots for all three of them. This exercise will involve:
#
# - splitting the data up in 3 groups: one for houses with a few rooms, one for houses with a "medium" amount of rooms, one for a high amount of rooms.
# - Create a function `build_interaction_rm`. This function takes an argument `varname` (which can be set equal to the column name as a string) and a column `description` (which describes the variable or varname, to be included on the x-axis of the plot). The function outputs a plot that uses "RM" as a confounding factor. Each plot should have three regression lines, one for each level of "RM."

# %% [markdown]
# The data has been split into high, medium and low number of rooms for you.

# %%
rm = np.asarray(df[["RM"]]).reshape(len(df[["RM"]]))

# %%
high_rm = all_data[rm > np.percentile(rm, 67)]
med_rm = all_data[(rm > np.percentile(rm, 33)) & (rm <= np.percentile(rm, 67))]
low_rm = all_data[rm <= np.percentile(rm, 33)]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-30-7c08287f6a0c> in <module>()
# ----> 1 high_rm = all_data[rm > np.percentile(rm, 67)]
#       2 med_rm = all_data[(rm > np.percentile(rm, 33)) & (rm <= np.percentile(rm, 67))]
#       3 low_rm = all_data[rm <= np.percentile(rm, 33)]
#
# NameError: name 'all_data' is not defined

# %% [markdown]
# Create `build_interaction_rm`.

# %%
def build_interaction_rm(varname, description):
    pass

# %% [markdown]
# Next, use build_interaction_rm with the three variables that came out with the highest effect on $R^2$

# %%
# first plot

# %%
# second plot

# %%
# third plot

# %% [markdown]
# ## Build a final model including all three interactions at once

# %% [markdown]
# Use 10-fold cross validation.

# %%
# code here

# %%
# code here

# %% [markdown]
# Our $R^2$ has increased considerably! Let's have a look in statsmodels to see if all these interactions are significant.

# %%
# code here

# %% [markdown]
# What is your conclusion here?

# %%
# formulate your conclusion

# %% [markdown]
# ## Summary

# %% [markdown]
# You should now understand how to include interaction effects in your model! As you can see, interactions can have a strong impact on linear regression models, and they should always be considered when you are constructing your models.
